# %% [markdown]
# <a href="https://colab.research.google.com/github/raguileoam/Colab/blob/master/CartopyColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Versión de Libproj depende de instalación de Cartopy

# %%
# !wget http://ftp.debian.org/debian/pool/main/p/proj/libproj13_5.2.0-1_amd64.deb
# !sudo dpkg -i libproj13_5.2.0-1_amd64.deb
# !rm libproj13_5.2.0-1_amd64.deb
# Out:
# --2019-11-03 00:38:41--  http://ftp.debian.org/debian/pool/main/p/proj/libproj13_5.2.0-1_amd64.deb
# Resolving ftp.debian.org (ftp.debian.org)... 130.89.148.12, 2001:67c:2564:a119::148:12
# Connecting to ftp.debian.org (ftp.debian.org)|130.89.148.12|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 224732 (219K) [application/x-debian-package]
# Saving to: ‘libproj13_5.2.0-1_amd64.deb’
#
# libproj13_5.2.0-1_a 100%[===================>] 219.46K   373KB/s    in 0.6s
#
# 2019-11-03 00:38:42 (373 KB/s) - ‘libproj13_5.2.0-1_amd64.deb’ saved [224732/224732]
#
# Selecting previously unselected package libproj13:amd64.
# (Reading database ... 132681 files and directories currently installed.)
# Preparing to unpack libproj13_5.2.0-1_amd64.deb ...
# Unpacking libproj13:amd64 (5.2.0-1) ...
# Setting up libproj13:amd64 (5.2.0-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %% [markdown]
# La última versión de Cartopy se descarga de la base de datos de Anaconda: https://anaconda.org/conda-forge/cartopy/files?sort=basename&sort_order=asc&version=0.17.0

# %%
# !wget https://anaconda.org/conda-forge/cartopy/0.17.0/download/linux-64/cartopy-0.17.0-py36h0aa2c8f_1004.tar.bz2
# !tar xvjf cartopy-0.17.0-py36h0aa2c8f_1004.tar.bz2
# !rm cartopy-0.17.0-py36h0aa2c8f_1004.tar.bz2
# !cp -r lib/python3.6/site-packages/* /usr/local/lib/python3.6/dist-packages/
# !rm -rf lib/python3.6/site-packages/*
# install dependencies
# !pip install shapely pyshp
#!apt install libproj-dev libgeos-dev
# finally
# Out:
# --2019-11-03 00:39:22--  https://anaconda.org/conda-forge/cartopy/0.17.0/download/linux-64/cartopy-0.17.0-py36h0aa2c8f_1004.tar.bz2
# Resolving anaconda.org (anaconda.org)... 104.17.93.24, 104.17.92.24, 2606:4700::6811:5c18, ...
# Connecting to anaconda.org (anaconda.org)|104.17.93.24|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# ...

# %%
import cartopy
